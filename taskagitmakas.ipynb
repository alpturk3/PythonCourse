# %% [markdown]
# <a href="https://colab.research.google.com/github/alpturk3/PythonCourse/blob/master/taskagitmakas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
a = ('tas', 'kagit', 'makas')
ekle = []
i = 0
for i in range(100) :
 x = random.choice(a)
 y = random.choice(a)
 
 if x == y:
  ekle.append('draw')
 elif (x == 'tas' and y == 'makas') or (x == 'kagit' and y == 'tas') or (x == 'makas' and y == 'kagit'):
  ekle.append('x wins')
 else:
  ekle.append('y wins')
print(ekle)
print(ekle.count('draw'))
print(ekle.count('x wins'))
print(ekle.count('y wins'))
